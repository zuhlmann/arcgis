# %%
# BASE FILES
gdb_str = 'klamath_d_drive2_gdb'
gdb_pro = pl.loc[gdb_str,'fp_gdb']
gdb_inv = pl.loc[gdb_str,'fname_csv']
inventory_dir = pl.loc[gdb_str,'inventory_dir']
gdb_inv
df = pd.read_csv(gdb_inv, index_col = 'ITEM')

# %%
feats = ['siskiyou_co_parcels_clipped','parcels_master_rectified_clipped']
fp_target = df.loc[feats[1],'DATA_LOCATION_MCMILLEN_JACOBS']
fp_source = df.loc[feats[0],'DATA_LOCATION_MCMILLEN_JACOBS']
fp_target = ol_translate(fp_target, gdb_str, True)
fp_source = ol_translate(fp_source, gdb_str, True)
fp_target = ol_translate(fp_target, gdb_str, True)
# Out:
# there
# there
# 'D:\\box_offline\\klamath\\GIS_Request_Tracking\\arcpro_maps\\klamath_d_drive2\\klamath_d_drive2.gdb\\parcels\\parcels_master_rectified_clipped'

# %%
# FIELD MAPPINGS
# From ddp_index Notebook on May 2022; Tried on Oct 2022 for this endeavor and it works.  
# But turned out merging was the incorrect approach
# Leaving here just for future fixing.  Does NOT work. 
import compare_data
importlib.reload(sys.modules['compare_data'])
fp_source = 'parcels_master_rectified_clipped'
fp_target = 'siskiyou_co_parcels_clipped'
csv = r'C:\Users\uhlmann\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Data\data_inventory_and_tracking\working_datasets\field_mapping_tables\parcels_master_rectified_fld_map.csv'
fm = compare_data.field_mapping_retain_src(fp_source, fp_target, csv)
# n = [n.outputField.baseName for n in fm.fieldMappings]
fp_out = os.path.join(gdb_pro, 'intermediary/parcels_merged')
arcpy.Merge_management([fp_source, fp_target], fp_out, fm, True)
# dir(fm.fieldMappings[0].outputField)
# Out:
# <Result 'D:\\box_offline\\klamath\\GIS_Request_Tracking\\arcpro_maps\\klamath_d_drive2\\klamath_d_drive2.gdb\\intermediary\\parcels_merged'>

# %%
# FIELD MAPPING
# Output field list to csv for formatting
# Created in May 2022; tested in October 2022 with parcels
# output comparison of tables to input into next cell
import copy

fp_in = ['parcels_master_rectified_clipped', 'siskiyou_co_parcels_clipped']
fld, fname = [],[]
df = pd.DataFrame(columns = ['feature_layer','field'])
for idx, f in enumerate(fp_in):
    if idx ==0:
        temp =[fs.name for fs in arcpy.ListFields(f)]
        fld = copy.copy(temp)
        fname = [f]*len(temp)
    else:
        temp = [fs.name for fs in arcpy.ListFields(f)]
        fld += copy.copy(temp)
        fname += [f]*len(temp)                     
    
df['field']=fld
df['feature_layer']=fname
path_csv = os.path.join(inventory_dir, 'parcels_master_siskiyou_join.csv')
df.to_csv(path_csv)

# %%
# # Formatting siskiyou for df join then update field

# # Files
# fp_source = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\parcels_master_rectified.csv'
# fp_target = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\siskiyou_co_parcels.csv'
# df_source = pd.read_csv(fp_source)
# df_target = pd.read_csv(fp_target)

# Siskiyou apn did NOT have trailing -000 in apn.  Added and joined to master
def format_apn(apn):
    try:
        int(apn[1])
        fmt = '{}-000'.format(apn)
    except ValueError:
        fmt = copy.copy(apn)
    return(fmt)
df_target['apn'] = df_target['apn'].apply(format_apn)
df_target.to_csv(fp_target)

# A) Prepare to subset siskiyou to only matching entries (Note - probably unnecessary)
# Get matching rows between master and siskiyou - 
matching_keys = set(df_source.apn).intersection(set(df_target.apn))
matching_keys = list(matching_keys)

# Use sql string in FC to FC
objid_sql = df_target.set_index('apn').loc[matching_keys,'OID_siskiyou'].to_list()
print(len(objid_sql))
objid_sql = [str(o) for o in objid_sql]
objid_sql = ','.join(objid_sql)
objid_sql = '"FID" IN ({})'.format(objid_sql)

# %%
# Subset to matching
wc = objid_sql
fp_out = os.path.join(gdb_pro,'parcels')
arcpy.FeatureClassToFeatureClass_conversion('siskiyou_co_parcels', fp_out, 'siskiyou_co_parcels_matched', where_clause = wc)
# Out:
# <Result 'D:\\box_offline\\klamath\\GIS_Request_Tracking\\arcpro_maps\\klamath_d_drive2\\klamath_d_drive2.gdb\\parcels\\siskiyou_co_parcels_matched'>

# %%
# After subsetting siskiyou parcels via matching_keys and formatting (fc_to_fc.keep_fields), 
# fix APN to match parcels master

# # a) Siskiyou apn did NOT have trailing -000 in apn.  Added and joined to master
# fp_target = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\siskiyou_co_parcels_matched_v2.csv'
# df_target = pd.read_csv(fp_target)

# def format_apn(apn):
#     try:
#         int(apn[1])
#         fmt = '{}-000'.format(apn)
#     except ValueError:
#         fmt = copy.copy(apn)
#     return(fmt)
# df_target['APN'] = df_target['APN'].apply(format_apn)
# df_target.to_csv(fp_target)

# b) update with new apn
utilities.update_field('siskiyou_co_parcels_matched_v2', r'apn_formatted', 1, False, fp_target)

# c) finish work
# remove extra apn field, whatever

# %%
# picking this up 2 months later for Local Impact Mitigation Func
# 20230113
import os
import pandas as pd
dir_out = r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Data\data_inventory_and_tracking\working_datasets\parcels'
csv = os.path.join(dir_out, r'parcels_siskiyou_dissolve_sample.csv')
df_diagnose = pd.read_csv(csv)
df_transposed = df_diagnose.T
df_transposed.to_csv(os.path.join(dir_out,r'parcels_sisk_sample_transposed.csv'))

# %%
# SQL statements for def queries per layer
import pandas as pd
csv = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\siskiyou_co_parcels_clipped.csv'
csv = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\parcels_master_rectified.csv'
csv = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\siskiyou_co_parcels_matched_v2.csv'
df=pd.read_csv(csv)
# temp = df.groupby('apn').count()
temp = df.groupby('apn').count()
temp = temp[temp['OID_']>1].index
objid_sql = "','".join(temp)
objid_sql = "'{}'".format(objid_sql)
objid_sql
# Out:
# "'003-010-130-000','004-010-010-000','004-020-030-000','004-030-371-000','004-040-060-000','004-040-350-000','004-040-471-000','004-050-010-000','004-050-380-000','004-060-100-000','004-180-280-000','004-190-030-000','004-380-030-000','004-393-291-000','004-393-531-000','004-400-680-000','004-460-261-000','004-460-281-000','004-490-171-000','004-510-331-000','004-530-011-000','004-530-021-000','004-530-031-000','004-540-071-000','004-540-081-000','004-540-091-000','004-540-101-000','004-550-011-000','004-550-031-000','004-550-071-000','004-550-081-000','004-550-091-000','006-020-020-000','006-030-160-000','006-050-060-000','006-060-060-000','006-150-020-000','006-160-030-000','006-160-040-000','006-240-030-000','006-240-310-000','006-250-430-000','006-250-460-000','006-270-010-000','006-280-060-000','006-360-110-000','006-450-040-000','006-450-100-000','006-470-070-000','006-470-150-000','006-480-060-000','006-500-140-000','007-090-090-000','007-140-080-000','007-280-170-000','007-340-080-000','007-370-050-000','007-420-110-000','007-460-220-000','007-480-160-000','008-130-130-000','008-151-150-000','008-160-300-000','008-160-320-000','008-220-060-000','008-380-590-000','008-400-110-000','008-440-300-000','008-450-040-000','008-550-150-000','009-520-130-000','011-010-110-000','011-010-160-000','011-130-090-000','011-150-100-000','011-160-150-000','013-020-110-000','013-030-450-000','013-030-480-000','013-040-110-000','013-060-180-000','013-260-080-000','013-270-040-000','013-270-160-000','013-490-470-000','013-500-080-000','013-500-540-000','013-510-430-000','013-630-220-000','014-050-070-000','014-140-090-000','014-140-100-000','014-150-060-000','014-150-110-000','014-160-050-000','014-160-160-000','014-181-100-000','014-190-180-000','015-270-180-000','015-280-170-000','016-010-240-000','016-010-280-000','016-110-050-000','016-190-050-000','016-190-060-000','016-240-020-000','016-240-030-000','016-270-390-000','016-290-320-000','016-370-020-000','016-421-470-000','026-180-070-000','026-190-110-000','026-190-130-000','026-220-080-000','026-240-030-000','026-240-050-000','026-240-130-000','026-240-150-000','026-240-210-000','026-240-220-000','026-240-230-000','026-240-240-000','026-250-070-000','026-260-140-000','026-290-330-000','026-540-060-000','026-540-070-000','026-540-100-000','026-540-110-000','026-540-120-000','026-540-130-000','033-070-070-000','033-080-230-000','033-090-060-000','033-090-090-000','033-100-120-000','033-110-070-000','033-130-200-000','033-130-330-000','033-600-050-000','033-610-080-000','033-610-180-000','040-100-050-000','040-160-020-000','040-180-310-000','040-240-170-000','040-270-210-000','040-330-020-000','040-362-370-000','040-370-040-000','041-020-160-000','041-030-200-000','041-050-020-000','041-080-130-000','041-080-150-000','041-080-420-000','041-080-440-000','041-080-470-000','041-080-480-000','041-120-170-000','041-131-040-000','041-131-150-000','041-131-180-000','041-131-310-000','041-150-140-000','041-190-110-000','041-200-070-000','041-220-010-000','041-280-040-000','041-280-150-000','041-290-040-000','041-290-080-000','041-302-100-000','041-302-250-000','041-360-090-000','053-061-510-000','053-591-320-000','053-621-340-000','103-080-380-000','103-200-320-000','2808-01700-00100','2808-01800-00100','30-3E-100','30-4E-100','31-2E-100','31-3E-100','32-1W-100','32-1W-1000','32-1W-1900','32-1W-2100','32-1W-2200','32-2E-17-1000','32-2E-17-700','32-2E-17-800','32-2E-2000','32-2E-2200','32-2E-2800','32-2E-3600','32-2E-3900','32-2E-400','32-2E-5001','32-2E-5100','32-2E-5700','32-2E-5800','32-2E-5900','32-2E-6800','32-2E-7200','32-2E-7400','32-2E-7500','32-3E-04-100','32-3E-05-100','32-3E-05-200','32-3E-06-100','32-3E-08-100','32-3E-08-200','32-3E-08-300','32-3E-09-100','32-3E-09-200','32-3E-15-300','32-3E-16-100','32-3E-17-100','32-3E-18-100','32-3E-19-100','32-3E-20-100','32-3E-22-100','32-3E-23-100','32-3E-27-100','32-3E-27-1501','32-3E-32-700','32-3E-33-100','32-3E-33-1900','32-3E-34-400','32- ...

# %%
import pandas as pd
csv_limf = r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\LIMF_confidential_att_table.csv'
csv_master = r'D:\box_offline\klamath\GIS_Request_Tracking\parcels_easements\parcels_master_rectified.csv'
df_limf = pd.read_csv(csv_limf, index_col='APN')
apns = df_limf.index
# df_master = pd.read_csv(csv_master, index_col = 'apn')

objid_sql = "','".join(apns)
objid_sql = "'{}'".format(objid_sql)
apns
# Out:
# Index(['004-030-421-000', '004-030-481-000', '004-030-661-000',
#        '004-040-681-000', '004-393-031-000', '004-393-061-000',
#        '004-393-071-000', '004-393-091-000', '004-393-161-000',
#        '004-393-171-000', '004-393-231-000', '004-393-241-000',
#        '004-393-261-000', '004-393-421-000', '004-393-441-000',
#        '004-393-471-000', '004-400-291-000', '004-400-301-000',
#        '004-400-371-000', '004-410-251-000', '004-420-021-000',
#        '004-420-031-000', '004-420-061-000', '004-420-081-000',
#        '004-420-101-000', '004-420-151-000', '004-420-461-000',
#        '004-420-471-000', '004-430-041-000', '004-430-121-000',
#        '004-430-131-000', '004-430-271-000', '004-430-301-000',
#        '004-430-401-000', '004-050-041-000', '004-050-281-000',
#        '004-030-460-000'],
#       dtype='object', name='APN')

# %%
base_dir = r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112'
csv_source =os.path.join(base_dir, r'LIMF_confidential_att_table.csv')
csv_target = os.path.join(base_dir, 'parcels_limf_v1.csv')
dft = pd.read_csv(csv_target)
dft = dft.set_index('apn')
dfs = pd.read_csv(csv_source)
dfs = dfs.set_index('APN')
df_joined = dft.join(dfs)
df_joined.to_csv(os.path.join(base_dir, 'parcels_limf_v1_joined.csv'))
# df_cols = pd.DataFrame(dft.columns)
# df_cols.to_csv(os.path.join(base_dir, 'limf_join_col_types.csv'))

# %%
csv_dict = os.path.join(base_dir, 'limf_join_dict.csv')
df_col_dict = pd.read_csv(csv_dict)
d = dict(zip(df_col_dict.orig, df_col_dict.shp_format))
dt = dict(zip(df_col_dict.shp_format, df_col_dict.typ))

# Renamed columns to shapefile format and saved
# df_joined = df_joined.rename(columns = d)
# df_joined.to_csv(os.path.join(base_dir, 'parcels_limf_v1_joined.csv'))

csv_joined =os.path.join(base_dir, 'parcels_limf_v1_joined.csv')
feat_name = 'parcels_limf_v1'
df_joined = pd.read_csv(csv_joined)
for c in df_joined.columns:
    try:
        if dt[c]=='lng':
            utilities.update_field(feat_name, c, 1, False, csv_joined, data_type = 'Long')
            print(r'LONG ', c)
        if dt[c]=='dbl':
            utilities.update_field(feat_name, c, 1, False, csv_joined, data_type = 'DOUBLE')
            print(r'DOUBLE ',c)
        if dt[c]=='stri':
            utilities.update_field(feat_name, c, 1, False, csv_joined)
            print(r'STRING ', c)
    except KeyError:
        print('!!!!{}'.format(c))
# Out:
# !!!!Unnamed: 0
# !!!!OID_
# !!!!site_address
# !!!!site_csz
# !!!!owner_name1
# !!!!owner_name2
# !!!!owner_address1
# !!!!owner_address2
# !!!!owner_csz
# !!!!care_of
# !!!!area_acres
# !!!!land_value
# !!!!imp_value
# !!!!total_value
# !!!!use_code
# !!!!tax_code
# !!!!islistedonexhibite4
# !!!!pacificorp_parceltype
# !!!!date_lastupdated
# !!!!county
# !!!!labelclass
# !!!!within_floodplain
# !!!!khsa_label
# !!!!source
# !!!!adjacent_property
# !!!!adj_reservoir
# !!!!OBJECTID
# !!!!apn_1
# !!!!symbol
# !!!!Shape_Length_1
# !!!!Shape_Area_1
# !!!!OBJECTID_1
# !!!!PARCELID
# !!!!APN_12
# !!!!AssesseeNa
# !!!!DBA
# !!!!InCareOf
# !!!!PSTLADDRES
# !!!!PSTLCITY
# !!!!PSTLSTATE
# !!!!PSTLZIP5
# !!!!PSTLZIP4
# !!!!SITEADDRES
# !!!!CVTTXCD
# !!!!USECD
# !!!!NGHBRHDCD
# !!!!Township
# !!!!Range
# !!!!Section
# !!!!Descr
# !!!!STATEDAREA
# !!!!LASTUPDATE
# !!!!CurrentDoc
# !!!!CurrentD_1
# !!!!Shape_Leng
# !!!!Shape_Length_12
# !!!!Shape_Area_12
# !!!!label
# !!!!Shape_Length
# !!!!Shape_Area
# ID_limf
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area']
# ----Adding field ID_limf ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 15
# 2. Original Val: None ---- New Val: 14
# 3. Original Val: None ---- New Val: 14
# 4. Original Val: None ---- New Val: 13
# 5. Original Val: None ---- New Val: 10
# 6. Original Val: None ---- New Val: 9
# 7. Original Val: None ---- New Val: 12
# 8. Original Val: None ---- New Val: 11
# 9. Original Val: None ---- New Val: 7
# 10. Original Val: None ---- New Val: 8
# 11. Original Val: None ---- New Val: 6
# 12. Original Val: None ---- New Val: 5
# 13. Original Val: None ---- New Val: NL
# 14. Original Val: None ---- New Val: 1
# 15. Original Val: None ---- New Val: 2
# 16. Original Val: None ---- New Val: 3
# 17. Original Val: None ---- New Val: 3
# 18. Original Val: None ---- New Val: 41
# 19. Original Val: None ---- New Val: 38
# 20. Original Val: None ---- New Val: 39
# 21. Original Val: None ---- New Val: 37
# 22. Original Val: None ---- New Val: 40
# 23. Original Val: None ---- New Val: NL
# 24. Original Val: None ---- New Val: 16
# 25. Original Val: None ---- New Val: NL
# 26. Original Val: None ---- New Val: 30
# 27. Original Val: None ---- New Val: 33
# 28. Original Val: None ---- New Val: 26
# 29. Original Val: None ---- New Val: 25
# 30. Original Val: None ---- New Val: 25
# 31. Original Val: None ---- New Val: 29
# 32. Original Val: None ---- New Val: 35
# 33. Original Val: None ---- New Val: 27
# 34. Original Val: None ---- New Val: 34
# 35. Original Val: None ---- New Val: 28
# 36. Original Val: None ---- New Val: 31
# 37. Original Val: None ---- New Val: 31
# 38. Original Val: None ---- New Val: 19
# 39. Original Val: None ---- New Val: 17
# 40. Original Val: None ---- New Val: 4
# 41. Original Val: None ---- New Val: 18
# STRING  ID_limf
# risk
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf']
# ----Adding field risk ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: High
# 2. Original Val: None ---- New Val: High
# 3. Original Val: None ---- New Val: High
# 4. Original Val: None ---- New Val: Low
# 5. Original Val: None ---- New Val: High
# 6. Original Val: None ---- New Val: High
# 7. Original Val: None ---- New Val: Low
# 8. Original Val: None ---- New Val: Low
# 9. Original Val: None ---- New Val: High
# 10. Original Val: None ---- New Val: High
# 11. Original Val: None ---- New Val: High
# 12. Original Val: None ---- New Val: High
# 13. Original Val: None ---- New Val: Medium
# 14. Original Val: None ---- New Val: High
# 15. Original Val: None ---- New Val: High
# 16. Original Val: None ---- New Val: High
# 17. Original Val: None ---- New Val: High
# 18. Original Val: None ---- New Val: High
# 19. Original Val: None ---- New Val: High
# 20. Original Val: None ---- New Val: High
# 21. Original Val: None ---- New Val: High
# 22. Original Val: None ---- New Val: High
# 23. Original Val: None ---- New Val: Medium
# 24. Original Val: None ---- New Val: High
# 25. Original Val: None ---- New Val: Medium
# 26. Original Val: None ---- New Val: High
# 27. Original Val: None ---- New Val: High
# 28. Original Val: None ---- New Val: High
# 29. Original Val: None ---- New Val: High
# 30. Original Val: None ---- New Val: High
# 31. Original Val: None ---- New Val: High
# 32. Original Val: None ---- New Val: High
# 33. Original Val: None ---- New Val: High
# 34. Original Val: None ---- New Val: High
# 35. Original Val: None ---- New Val: High
# 36. Original Val: None ---- New Val: High
# 37. Original Val: None ---- New Val: High
# 38. Original Val: None ---- New Val: Low
# 39. Original Val: None ---- New Val: High
# 40. Original Val: None ---- New Val: High
# 41. Original Val: None ---- New Val: High
# STRING  risk
# user_type
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk']
# ----Adding field user_type ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 2. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 3. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 4. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 5. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 6. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 7. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 8. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 9. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 10. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 11. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 12. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 13. Original Val: None ---- New Val: Vacant
# 14. Original Val: None ---- New Val: RESIDENTIAL
# 15. Original Val: None ---- New Val: RESIDENTIAL
# 16. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 17. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 18. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 19. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 20. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 21. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 22. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 23. Original Val: None ---- New Val: Vacant
# 24. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 25. Original Val: None ---- New Val: Vacant
# 26. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 27. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 28. Original Val: None ---- New Val: RESID. MULTIPLE FAMILY
# 29. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 30. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 31. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 32. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 33. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 34. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 35. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 36. Original Val: None ---- New Val: RESID. MULTIPLE FAMILY
# 37. Original Val: None ---- New Val: RESID. MULTIPLE FAMILY
# 38. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 39. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 40. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# 41. Original Val: None ---- New Val: RESID. SINGLE FAMILY
# STRING  user_type
# street
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type']
# ----Adding field street ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 21205 AGER BESWICK RD
# 2. Original Val: None ---- New Val: 21115 AGER BESWICK RD
# 3. Original Val: None ---- New Val: 21115 AGER BESWICK RD
# 4. Original Val: None ---- New Val: 20841 AGER BESWICK RD
# 5. Original Val: None ---- New Val: 20709 AGER BESWICK RD
# 6. Original Val: None ---- New Val: 20701 AGER BESWICK RD
# 7. Original Val: None ---- New Val: 20815 AGER BESWICK RD
# 8. Original Val: None ---- New Val: 20805 AGER BESWICK RD
# 9. Original Val: None ---- New Val: 20421 AGER BESWICK RD
# 10. Original Val: None ---- New Val: 20439 AGER BESWICK RD
# 11. Original Val: None ---- New Val: 20333 AGER BESWICK RD
# 12. Original Val: None ---- New Val: 20231 AGER BESWICK RD
# 13. Original Val: None ---- New Val: Undefined
# 14. Original Val: None ---- New Val: 26516 COPCO RD
# 15. Original Val: None ---- New Val: 26734 COPCO RD
# 16. Original Val: None ---- New Val: 26834 COPCO RD
# 17. Original Val: None ---- New Val: 26834 COPCO RD
# 18. Original Val: None ---- New Val: 16739 PATRICIA AVE
# 19. Original Val: None ---- New Val: 16631 PATRICIA AVE
# 20. Original Val: None ---- New Val: 16801 PATRICIA AVE
# 21. Original Val: None ---- New Val: 16635 PATRICIA AVE
# 22. Original Val: None ---- New Val: 16705 PATRICIA AVE
# 23. Original Val: None ---- New Val: Undefined
# 24. Original Val: None ---- New Val: 21235 AGER BESWICK RD
# 25. Original Val: None ---- New Val: Undefined
# 26. Original Val: None ---- New Val: 17125 PATRICIA AVE
# 27. Original Val: None ---- New Val: 17601 PATRICIA AVE
# 28. Original Val: None ---- New Val: 17011 PATRICIA AVE
# 29. Original Val: None ---- New Val: 17635 PATRICIA AVE
# 30. Original Val: None ---- New Val: 17635 PATRICIA AVE
# 31. Original Val: None ---- New Val: 17107 PATRICIA AVE
# 32. Original Val: None ---- New Val: 16817 PATRICIA AVE
# 33. Original Val: None ---- New Val: 17025 PATRICIA AVE
# 34. Original Val: None ---- New Val: 17433 PATRICIA AVE
# 35. Original Val: None ---- New Val: 17105 PATRICIA AVE
# 36. Original Val: None ---- New Val: 17411 PATRICIA AVE
# 37. Original Val: None ---- New Val: 17411 PATRICIA AVE
# 38. Original Val: None ---- New Val: 16720 JACQUELINE AVE
# 39. Original Val: None ---- New Val: 16900 JACQUELINE AVE
# 40. Original Val: None ---- New Val: 19225 AGER BESWICK RD
# 41. Original Val: None ---- New Val: 16838 JACQUELINE AVE
# STRING  street
# city_st
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street']
# ----Adding field city_st ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: MONTAGUE CA 96064-9469
# 2. Original Val: None ---- New Val: MONTAGUE CA 96064-9469
# 3. Original Val: None ---- New Val: MONTAGUE CA 96064-9469
# 4. Original Val: None ---- New Val: MONTAGUE CA 96064-9468
# 5. Original Val: None ---- New Val: MONTAGUE CA 96064-9468
# 6. Original Val: None ---- New Val: MONTAGUE CA 96064-9468
# 7. Original Val: None ---- New Val: MONTAGUE CA 96064-9468
# 8. Original Val: None ---- New Val: MONTAGUE CA 96064-9468
# 9. Original Val: None ---- New Val: MONTAGUE CA 96064-9486
# 10. Original Val: None ---- New Val: MONTAGUE CA 96064-9486
# 11. Original Val: None ---- New Val: MONTAGUE CA 96064-9631
# 12. Original Val: None ---- New Val: MONTAGUE CA 96064-9470
# 13. Original Val: None ---- New Val: MONTAGUE CA 96064
# 14. Original Val: None ---- New Val: MONTAGUE CA 96064-9438
# 15. Original Val: None ---- New Val: MONTAGUE CA 96064-9438
# 16. Original Val: None ---- New Val: MONTAGUE CA 96064-9632
# 17. Original Val: None ---- New Val: MONTAGUE CA 96064-9632
# 18. Original Val: None ---- New Val: MONTAGUE CA 96064-9443
# 19. Original Val: None ---- New Val: MONTAGUE CA 96064-9443
# 20. Original Val: None ---- New Val: MONTAGUE CA 96064-9482
# 21. Original Val: None ---- New Val: MONTAGUE CA 96064-9443
# 22. Original Val: None ---- New Val: MONTAGUE CA 96064-9443
# 23. Original Val: None ---- New Val: MONTAGUE CA 96064
# 24. Original Val: None ---- New Val: MONTAGUE CA 96064-9469
# 25. Original Val: None ---- New Val: MONTAGUE CA 96064
# 26. Original Val: None ---- New Val: MONTAGUE CA 96064-9492
# 27. Original Val: None ---- New Val: MONTAGUE CA 96064-9485
# 28. Original Val: None ---- New Val: MONTAGUE CA 96064-9483
# 29. Original Val: None ---- New Val: MONTAGUE CA 96064-9485
# 30. Original Val: None ---- New Val: MONTAGUE CA 96064-9485
# 31. Original Val: None ---- New Val: MONTAGUE CA 96064-9492
# 32. Original Val: None ---- New Val: MONTAGUE CA 96064-9482
# 33. Original Val: None ---- New Val: MONTAGUE CA 96064-9483
# 34. Original Val: None ---- New Val: MONTAGUE CA 96064-9484
# 35. Original Val: None ---- New Val: MONTAGUE CA 96064-9492
# 36. Original Val: None ---- New Val: MONTAGUE CA 96064-9484
# 37. Original Val: None ---- New Val: MONTAGUE CA 96064-9484
# 38. Original Val: None ---- New Val: MONTAGUE CA 96064-9442
# 39. Original Val: None ---- New Val: MONTAGUE CA 96064-9442
# 40. Original Val: None ---- New Val: MONTAGUE CA 96064-9467
# 41. Original Val: None ---- New Val: MONTAGUE CA 96064-9442
# STRING  city_st
# assesss_val
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st']
# ----Adding field assesss_val ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 90000.0
# 2. Original Val: None ---- New Val: 181853.0
# 3. Original Val: None ---- New Val: 181853.0
# 4. Original Val: None ---- New Val: 115000.0
# 5. Original Val: None ---- New Val: 53141.0
# 6. Original Val: None ---- New Val: 48419.0
# 7. Original Val: None ---- New Val: 124000.0
# 8. Original Val: None ---- New Val: 184620.0
# 9. Original Val: None ---- New Val: 120000.0
# 10. Original Val: None ---- New Val: 142304.0
# 11. Original Val: None ---- New Val: 310000.0
# 12. Original Val: None ---- New Val: 99351.0
# 13. Original Val: None ---- New Val: 198425.0
# 14. Original Val: None ---- New Val: 250097.0
# 15. Original Val: None ---- New Val: 335000.0
# 16. Original Val: None ---- New Val: 183000.0
# 17. Original Val: None ---- New Val: 183000.0
# 18. Original Val: None ---- New Val: 240298.0
# 19. Original Val: None ---- New Val: 139155.0
# 20. Original Val: None ---- New Val: 80000.0
# 21. Original Val: None ---- New Val: 160061.0
# 22. Original Val: None ---- New Val: 122528.0
# 23. Original Val: None ---- New Val: 46837.0
# 24. Original Val: None ---- New Val: 66000.0
# 25. Original Val: None ---- New Val: 34357.0
# 26. Original Val: None ---- New Val: 70002.0
# 27. Original Val: None ---- New Val: 205000.0
# 28. Original Val: None ---- New Val: 205000.0
# 29. Original Val: None ---- New Val: 201978.0
# 30. Original Val: None ---- New Val: 201978.0
# 31. Original Val: None ---- New Val: 117000.0
# 32. Original Val: None ---- New Val: 145000.0
# 33. Original Val: None ---- New Val: 110000.0
# 34. Original Val: None ---- New Val: 298381.0
# 35. Original Val: None ---- New Val: 160000.0
# 36. Original Val: None ---- New Val: 180476.0
# 37. Original Val: None ---- New Val: 180476.0
# 38. Original Val: None ---- New Val: 158100.0
# 39. Original Val: None ---- New Val: 75626.0
# 40. Original Val: None ---- New Val: 100000.0
# 41. Original Val: None ---- New Val: 65438.0
# DOUBLE  assesss_val
# sale_list
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val']
# ----Adding field sale_list ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: Sale
# 2. Original Val: None ---- New Val: nan
# 3. Original Val: None ---- New Val: nan
# 4. Original Val: None ---- New Val: nan
# 5. Original Val: None ---- New Val: nan
# 6. Original Val: None ---- New Val: nan
# 7. Original Val: None ---- New Val: Sale
# 8. Original Val: None ---- New Val: Sale
# 9. Original Val: None ---- New Val: Sale
# 10. Original Val: None ---- New Val: nan
# 11. Original Val: None ---- New Val: nan
# 12. Original Val: None ---- New Val: Sale
# 13. Original Val: None ---- New Val: nan
# 14. Original Val: None ---- New Val: nan
# 15. Original Val: None ---- New Val: Sale
# 16. Original Val: None ---- New Val: nan
# 17. Original Val: None ---- New Val: nan
# 18. Original Val: None ---- New Val: Sale
# 19. Original Val: None ---- New Val: Listing
# 20. Original Val: None ---- New Val: nan
# 21. Original Val: None ---- New Val: Sale
# 22. Original Val: None ---- New Val: Sale
# 23. Original Val: None ---- New Val: nan
# 24. Original Val: None ---- New Val: nan
# 25. Original Val: None ---- New Val: nan
# 26. Original Val: None ---- New Val: nan
# 27. Original Val: None ---- New Val: Listing
# 28. Original Val: None ---- New Val: nan
# 29. Original Val: None ---- New Val: Listing
# 30. Original Val: None ---- New Val: Listing
# 31. Original Val: None ---- New Val: nan
# 32. Original Val: None ---- New Val: Sale
# 33. Original Val: None ---- New Val: Sale
# 34. Original Val: None ---- New Val: Sale
# 35. Original Val: None ---- New Val: nan
# 36. Original Val: None ---- New Val: Listing
# 37. Original Val: None ---- New Val: Listing
# 38. Original Val: None ---- New Val: Sale
# 39. Original Val: None ---- New Val: nan
# 40. Original Val: None ---- New Val: nan
# 41. Original Val: None ---- New Val: nan
# STRING  sale_list
# last_price
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list']
# ----Adding field last_price ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 189000.0
# 2. Original Val: None ---- New Val: nan
# 3. Original Val: None ---- New Val: nan
# 4. Original Val: None ---- New Val: nan
# 5. Original Val: None ---- New Val: nan
# 6. Original Val: None ---- New Val: nan
# 7. Original Val: None ---- New Val: 150000.0
# 8. Original Val: None ---- New Val: 192500.0
# 9. Original Val: None ---- New Val: 145000.0
# 10. Original Val: None ---- New Val: nan
# 11. Original Val: None ---- New Val: nan
# 12. Original Val: None ---- New Val: 57000.0
# 13. Original Val: None ---- New Val: nan
# 14. Original Val: None ---- New Val: nan
# 15. Original Val: None ---- New Val: 389479.0
# 16. Original Val: None ---- New Val: nan
# 17. Original Val: None ---- New Val: nan
# 18. Original Val: None ---- New Val: 249000.0
# 19. Original Val: None ---- New Val: 299000.0
# 20. Original Val: None ---- New Val: nan
# 21. Original Val: None ---- New Val: 52500.0
# 22. Original Val: None ---- New Val: 115000.0
# 23. Original Val: None ---- New Val: nan
# 24. Original Val: None ---- New Val: nan
# 25. Original Val: None ---- New Val: nan
# 26. Original Val: None ---- New Val: nan
# 27. Original Val: None ---- New Val: 335000.0
# 28. Original Val: None ---- New Val: nan
# 29. Original Val: None ---- New Val: 269000.0
# 30. Original Val: None ---- New Val: 269000.0
# 31. Original Val: None ---- New Val: nan
# 32. Original Val: None ---- New Val: 140000.0
# 33. Original Val: None ---- New Val: 177000.0
# 34. Original Val: None ---- New Val: 315000.0
# 35. Original Val: None ---- New Val: nan
# 36. Original Val: None ---- New Val: 239900.0
# 37. Original Val: None ---- New Val: 239900.0
# 38. Original Val: None ---- New Val: 155000.0
# 39. Original Val: None ---- New Val: nan
# 40. Original Val: None ---- New Val: nan
# 41. Original Val: None ---- New Val: nan
# DOUBLE  last_price
# year
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price']
# ----Adding field year ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 2019.0
# 2. Original Val: None ---- New Val: nan
# 3. Original Val: None ---- New Val: nan
# 4. Original Val: None ---- New Val: nan
# 5. Original Val: None ---- New Val: nan
# 6. Original Val: None ---- New Val: nan
# 7. Original Val: None ---- New Val: 2018.0
# 8. Original Val: None ---- New Val: 2018.0
# 9. Original Val: None ---- New Val: 2002.0
# 10. Original Val: None ---- New Val: nan
# 11. Original Val: None ---- New Val: nan
# 12. Original Val: None ---- New Val: 2014.0
# 13. Original Val: None ---- New Val: nan
# 14. Original Val: None ---- New Val: nan
# 15. Original Val: None ---- New Val: 2008.0
# 16. Original Val: None ---- New Val: nan
# 17. Original Val: None ---- New Val: nan
# 18. Original Val: None ---- New Val: 2015.0
# 19. Original Val: None ---- New Val: 2019.0
# 20. Original Val: None ---- New Val: nan
# 21. Original Val: None ---- New Val: 2012.0
# 22. Original Val: None ---- New Val: 2011.0
# 23. Original Val: None ---- New Val: nan
# 24. Original Val: None ---- New Val: nan
# 25. Original Val: None ---- New Val: nan
# 26. Original Val: None ---- New Val: nan
# 27. Original Val: None ---- New Val: 2019.0
# 28. Original Val: None ---- New Val: nan
# 29. Original Val: None ---- New Val: 2018.0
# 30. Original Val: None ---- New Val: 2018.0
# 31. Original Val: None ---- New Val: nan
# 32. Original Val: None ---- New Val: 2002.0
# 33. Original Val: None ---- New Val: 2018.0
# 34. Original Val: None ---- New Val: 2019.0
# 35. Original Val: None ---- New Val: nan
# 36. Original Val: None ---- New Val: 2012.0
# 37. Original Val: None ---- New Val: 2012.0
# 38. Original Val: None ---- New Val: 2016.0
# 39. Original Val: None ---- New Val: nan
# 40. Original Val: None ---- New Val: nan
# 41. Original Val: None ---- New Val: nan
# LONG  year
# RES_est_val
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year']
# ----Adding field RES_est_val ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 112500.0
# 2. Original Val: None ---- New Val: 227316.25
# 3. Original Val: None ---- New Val: 227316.25
# 4. Original Val: None ---- New Val: 143750.0
# 5. Original Val: None ---- New Val: 66426.25
# 6. Original Val: None ---- New Val: 60523.75
# 7. Original Val: None ---- New Val: 155000.0
# 8. Original Val: None ---- New Val: 230775.0
# 9. Original Val: None ---- New Val: 150000.0
# 10. Original Val: None ---- New Val: 177880.0
# 11. Original Val: None ---- New Val: 387500.0
# 12. Original Val: None ---- New Val: 124188.75
# 13. Original Val: None ---- New Val: 248031.25
# 14. Original Val: None ---- New Val: 312621.25
# 15. Original Val: None ---- New Val: 418750.0
# 16. Original Val: None ---- New Val: 228750.0
# 17. Original Val: None ---- New Val: 228750.0
# 18. Original Val: None ---- New Val: 300372.5
# 19. Original Val: None ---- New Val: 173943.75
# 20. Original Val: None ---- New Val: 100000.0
# 21. Original Val: None ---- New Val: 200076.25
# 22. Original Val: None ---- New Val: 153160.0
# 23. Original Val: None ---- New Val: 58546.25
# 24. Original Val: None ---- New Val: 82500.0
# 25. Original Val: None ---- New Val: 42946.25
# 26. Original Val: None ---- New Val: 87502.5
# 27. Original Val: None ---- New Val: 256250.0
# 28. Original Val: None ---- New Val: 256250.0
# 29. Original Val: None ---- New Val: 252472.5
# 30. Original Val: None ---- New Val: 252472.5
# 31. Original Val: None ---- New Val: 146250.0
# 32. Original Val: None ---- New Val: 181250.0
# 33. Original Val: None ---- New Val: 137500.0
# 34. Original Val: None ---- New Val: 372976.25
# 35. Original Val: None ---- New Val: 200000.0
# 36. Original Val: None ---- New Val: 225595.0
# 37. Original Val: None ---- New Val: 225595.0
# 38. Original Val: None ---- New Val: 197625.0
# 39. Original Val: None ---- New Val: 94532.5
# 40. Original Val: None ---- New Val: 125000.0
# 41. Original Val: None ---- New Val: 81797.5
# DOUBLE  RES_est_val
# reduce_val1
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val']
# ----Adding field reduce_val1 ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 16875.0
# 2. Original Val: None ---- New Val: 34097.4375
# 3. Original Val: None ---- New Val: 34097.4375
# 4. Original Val: None ---- New Val: 21562.5
# 5. Original Val: None ---- New Val: 9963.9375
# 6. Original Val: None ---- New Val: 9078.5625
# 7. Original Val: None ---- New Val: 23250.0
# 8. Original Val: None ---- New Val: 34616.25
# 9. Original Val: None ---- New Val: 22500.0
# 10. Original Val: None ---- New Val: 26682.0
# 11. Original Val: None ---- New Val: 58125.0
# 12. Original Val: None ---- New Val: 18628.3125
# 13. Original Val: None ---- New Val: 37204.6875
# 14. Original Val: None ---- New Val: 46893.1875
# 15. Original Val: None ---- New Val: 62812.5
# 16. Original Val: None ---- New Val: 34312.5
# 17. Original Val: None ---- New Val: 34312.5
# 18. Original Val: None ---- New Val: 45055.875
# 19. Original Val: None ---- New Val: 26091.5625
# 20. Original Val: None ---- New Val: 15000.0
# 21. Original Val: None ---- New Val: 30011.4375
# 22. Original Val: None ---- New Val: 22974.0
# 23. Original Val: None ---- New Val: 8781.9375
# 24. Original Val: None ---- New Val: 12375.0
# 25. Original Val: None ---- New Val: 6441.9375
# 26. Original Val: None ---- New Val: 13125.375
# 27. Original Val: None ---- New Val: 38437.5
# 28. Original Val: None ---- New Val: 38437.5
# 29. Original Val: None ---- New Val: 37870.875
# 30. Original Val: None ---- New Val: 37870.875
# 31. Original Val: None ---- New Val: 21937.5
# 32. Original Val: None ---- New Val: 27187.5
# 33. Original Val: None ---- New Val: 20625.0
# 34. Original Val: None ---- New Val: 55946.4375
# 35. Original Val: None ---- New Val: 30000.0
# 36. Original Val: None ---- New Val: 33839.25
# 37. Original Val: None ---- New Val: 33839.25
# 38. Original Val: None ---- New Val: 29643.75
# 39. Original Val: None ---- New Val: 14179.875
# 40. Original Val: None ---- New Val: 18750.0
# 41. Original Val: None ---- New Val: 12269.625
# DOUBLE  reduce_val1
# reduce_val2
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val', 'reduce_val1']
# ----Adding field reduce_val2 ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 101250.0
# 2. Original Val: None ---- New Val: 204584.625
# 3. Original Val: None ---- New Val: 204584.625
# 4. Original Val: None ---- New Val: 129375.0
# 5. Original Val: None ---- New Val: 59783.625
# 6. Original Val: None ---- New Val: 54471.375
# 7. Original Val: None ---- New Val: 139500.0
# 8. Original Val: None ---- New Val: 207697.5
# 9. Original Val: None ---- New Val: 135000.0
# 10. Original Val: None ---- New Val: 160092.0
# 11. Original Val: None ---- New Val: 348750.0
# 12. Original Val: None ---- New Val: 111769.875
# 13. Original Val: None ---- New Val: 223228.125
# 14. Original Val: None ---- New Val: 281359.125
# 15. Original Val: None ---- New Val: 376875.0
# 16. Original Val: None ---- New Val: 205875.0
# 17. Original Val: None ---- New Val: 205875.0
# 18. Original Val: None ---- New Val: 270335.25
# 19. Original Val: None ---- New Val: 156549.375
# 20. Original Val: None ---- New Val: 90000.0
# 21. Original Val: None ---- New Val: 180068.625
# 22. Original Val: None ---- New Val: 137844.0
# 23. Original Val: None ---- New Val: 52691.625
# 24. Original Val: None ---- New Val: 74250.0
# 25. Original Val: None ---- New Val: 38651.625
# 26. Original Val: None ---- New Val: 78752.25
# 27. Original Val: None ---- New Val: 230625.0
# 28. Original Val: None ---- New Val: 230625.0
# 29. Original Val: None ---- New Val: 227225.25
# 30. Original Val: None ---- New Val: 227225.25
# 31. Original Val: None ---- New Val: 131625.0
# 32. Original Val: None ---- New Val: 163125.0
# 33. Original Val: None ---- New Val: 123750.0
# 34. Original Val: None ---- New Val: 335678.625
# 35. Original Val: None ---- New Val: 180000.0
# 36. Original Val: None ---- New Val: 203035.5
# 37. Original Val: None ---- New Val: 203035.5
# 38. Original Val: None ---- New Val: 177862.5
# 39. Original Val: None ---- New Val: 85079.25
# 40. Original Val: None ---- New Val: 112500.0
# 41. Original Val: None ---- New Val: 73617.75
# DOUBLE  reduce_val2
# limf_alloc_lo
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val', 'reduce_val1', 'reduce_val2']
# ----Adding field limf_alloc_lo ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 16875.0
# 2. Original Val: None ---- New Val: 34097.4375
# 3. Original Val: None ---- New Val: 34097.4375
# 4. Original Val: None ---- New Val: 21562.5
# 5. Original Val: None ---- New Val: 9963.9375
# 6. Original Val: None ---- New Val: 9078.5625
# 7. Original Val: None ---- New Val: 23250.0
# 8. Original Val: None ---- New Val: 34616.25
# 9. Original Val: None ---- New Val: 22500.0
# 10. Original Val: None ---- New Val: 26682.0
# 11. Original Val: None ---- New Val: 58125.0
# 12. Original Val: None ---- New Val: 18628.3125
# 13. Original Val: None ---- New Val: 0.0
# 14. Original Val: None ---- New Val: 46893.1875
# 15. Original Val: None ---- New Val: 62812.5
# 16. Original Val: None ---- New Val: 34312.5
# 17. Original Val: None ---- New Val: 34312.5
# 18. Original Val: None ---- New Val: 45055.875
# 19. Original Val: None ---- New Val: 26091.5625
# 20. Original Val: None ---- New Val: 15000.0
# 21. Original Val: None ---- New Val: 30011.4375
# 22. Original Val: None ---- New Val: 22974.0
# 23. Original Val: None ---- New Val: 0.0
# 24. Original Val: None ---- New Val: 12375.0
# 25. Original Val: None ---- New Val: 0.0
# 26. Original Val: None ---- New Val: 13125.375
# 27. Original Val: None ---- New Val: 38437.5
# 28. Original Val: None ---- New Val: 38437.5
# 29. Original Val: None ---- New Val: 37870.875
# 30. Original Val: None ---- New Val: 37870.875
# 31. Original Val: None ---- New Val: 21937.5
# 32. Original Val: None ---- New Val: 27187.5
# 33. Original Val: None ---- New Val: 20625.0
# 34. Original Val: None ---- New Val: 55946.4375
# 35. Original Val: None ---- New Val: 30000.0
# 36. Original Val: None ---- New Val: 33839.25
# 37. Original Val: None ---- New Val: 33839.25
# 38. Original Val: None ---- New Val: 29643.75
# 39. Original Val: None ---- New Val: 14179.875
# 40. Original Val: None ---- New Val: 18750.0
# 41. Original Val: None ---- New Val: 12269.625
# DOUBLE  limf_alloc_lo
# limf_alloc_hi
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val', 'reduce_val1', 'reduce_val2', 'limf_alloc_lo']
# ----Adding field limf_alloc_hi ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 101250.0
# 2. Original Val: None ---- New Val: 204584.625
# 3. Original Val: None ---- New Val: 204584.625
# 4. Original Val: None ---- New Val: 21562.5
# 5. Original Val: None ---- New Val: 59783.625
# 6. Original Val: None ---- New Val: 54471.375
# 7. Original Val: None ---- New Val: 23250.0
# 8. Original Val: None ---- New Val: 34616.25
# 9. Original Val: None ---- New Val: 135000.0
# 10. Original Val: None ---- New Val: 160092.0
# 11. Original Val: None ---- New Val: 348750.0
# 12. Original Val: None ---- New Val: 111769.875
# 13. Original Val: None ---- New Val: 0.0
# 14. Original Val: None ---- New Val: 281359.125
# 15. Original Val: None ---- New Val: 376875.0
# 16. Original Val: None ---- New Val: 205875.0
# 17. Original Val: None ---- New Val: 205875.0
# 18. Original Val: None ---- New Val: 270335.25
# 19. Original Val: None ---- New Val: 156549.375
# 20. Original Val: None ---- New Val: 90000.0
# 21. Original Val: None ---- New Val: 180068.625
# 22. Original Val: None ---- New Val: 137844.0
# 23. Original Val: None ---- New Val: 0.0
# 24. Original Val: None ---- New Val: 74250.0
# 25. Original Val: None ---- New Val: 0.0
# 26. Original Val: None ---- New Val: 78752.25
# 27. Original Val: None ---- New Val: 230625.0
# 28. Original Val: None ---- New Val: 230625.0
# 29. Original Val: None ---- New Val: 227225.25
# 30. Original Val: None ---- New Val: 227225.25
# 31. Original Val: None ---- New Val: 131625.0
# 32. Original Val: None ---- New Val: 163125.0
# 33. Original Val: None ---- New Val: 123750.0
# 34. Original Val: None ---- New Val: 335678.625
# 35. Original Val: None ---- New Val: 180000.0
# 36. Original Val: None ---- New Val: 203035.5
# 37. Original Val: None ---- New Val: 203035.5
# 38. Original Val: None ---- New Val: 29643.75
# 39. Original Val: None ---- New Val: 85079.25
# 40. Original Val: None ---- New Val: 112500.0
# 41. Original Val: None ---- New Val: 73617.75
# DOUBLE  limf_alloc_hi
# per_diem
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val', 'reduce_val1', 'reduce_val2', 'limf_alloc_lo', 'limf_alloc_hi']
# ----Adding field per_diem ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: 16920.0
# 2. Original Val: None ---- New Val: 16920.0
# 3. Original Val: None ---- New Val: 16920.0
# 4. Original Val: None ---- New Val: 0.0
# 5. Original Val: None ---- New Val: 16920.0
# 6. Original Val: None ---- New Val: 16920.0
# 7. Original Val: None ---- New Val: 0.0
# 8. Original Val: None ---- New Val: 0.0
# 9. Original Val: None ---- New Val: 16920.0
# 10. Original Val: None ---- New Val: 16920.0
# 11. Original Val: None ---- New Val: 16920.0
# 12. Original Val: None ---- New Val: 16920.0
# 13. Original Val: None ---- New Val: 16920.0
# 14. Original Val: None ---- New Val: 16920.0
# 15. Original Val: None ---- New Val: 16920.0
# 16. Original Val: None ---- New Val: 16920.0
# 17. Original Val: None ---- New Val: 16920.0
# 18. Original Val: None ---- New Val: 16920.0
# 19. Original Val: None ---- New Val: 16920.0
# 20. Original Val: None ---- New Val: 16920.0
# 21. Original Val: None ---- New Val: 16920.0
# 22. Original Val: None ---- New Val: 16920.0
# 23. Original Val: None ---- New Val: 16920.0
# 24. Original Val: None ---- New Val: 16920.0
# 25. Original Val: None ---- New Val: 16920.0
# 26. Original Val: None ---- New Val: 16920.0
# 27. Original Val: None ---- New Val: 16920.0
# 28. Original Val: None ---- New Val: 16920.0
# 29. Original Val: None ---- New Val: 16920.0
# 30. Original Val: None ---- New Val: 16920.0
# 31. Original Val: None ---- New Val: 16920.0
# 32. Original Val: None ---- New Val: 16920.0
# 33. Original Val: None ---- New Val: 16920.0
# 34. Original Val: None ---- New Val: 16920.0
# 35. Original Val: None ---- New Val: 16920.0
# 36. Original Val: None ---- New Val: 16920.0
# 37. Original Val: None ---- New Val: 16920.0
# 38. Original Val: None ---- New Val: 0.0
# 39. Original Val: None ---- New Val: 16920.0
# 40. Original Val: None ---- New Val: 16920.0
# 41. Original Val: None ---- New Val: 16920.0
# DOUBLE  per_diem
# notes
# ['OBJECTID_12', 'Shape', 'apn', 'site_address', 'site_csz', 'owner_name1', 'owner_name2', 'owner_address1', 'owner_address2', 'owner_csz', 'care_of', 'area_acres', 'land_value', 'imp_value', 'total_value', 'use_code', 'tax_code', 'islistedonexhibite4', 'pacificorp_parceltype', 'date_lastupdated', 'county', 'labelclass', 'within_floodplain', 'khsa_label', 'source', 'adjacent_property', 'adj_reservoir', 'OBJECTID', 'apn_1', 'symbol', 'Shape_Length_1', 'Shape_Area_1', 'OBJECTID_1', 'PARCELID', 'APN_12', 'AssesseeNa', 'DBA', 'InCareOf', 'PSTLADDRES', 'PSTLCITY', 'PSTLSTATE', 'PSTLZIP5', 'PSTLZIP4', 'SITEADDRES', 'CVTTXCD', 'USECD', 'NGHBRHDCD', 'Township', 'Range', 'Section', 'Descr', 'STATEDAREA', 'LASTUPDATE', 'CurrentDoc', 'CurrentD_1', 'Shape_Leng', 'Shape_Length_12', 'Shape_Area_12', 'label', 'Shape_Length', 'Shape_Area', 'ID_limf', 'risk', 'user_type', 'street', 'city_st', 'assesss_val', 'sale_list', 'last_price', 'year', 'RES_est_val', 'reduce_val1', 'reduce_val2', 'limf_alloc_lo', 'limf_alloc_hi', 'per_diem']
# ----Adding field notes ----
# ----Updating Cursor ---
# 1. Original Val: None ---- New Val: nan
# 2. Original Val: None ---- New Val: nan
# 3. Original Val: None ---- New Val: nan
# 4. Original Val: None ---- New Val: Low risk property and thus "low" reduction in value number was used.
# 5. Original Val: None ---- New Val: nan
# 6. Original Val: None ---- New Val: nan
# 7. Original Val: None ---- New Val: Low risk property and thus "low" reduction in value number was used.
# 8. Original Val: None ---- New Val: Low risk property and thus "low" reduction in value number was used.
# 9. Original Val: None ---- New Val: Last sale was 18 years ago
# 10. Original Val: None ---- New Val: nan
# 11. Original Val: None ---- New Val: nan
# 12. Original Val: None ---- New Val: Last sale was below assessed value.
# 13. Original Val: None ---- New Val: We understand these properties are owned by PAC and, thus, no compensation is needed.
# 14. Original Val: None ---- New Val: nan
# 15. Original Val: None ---- New Val: nan
# 16. Original Val: None ---- New Val: nan
# 17. Original Val: None ---- New Val: nan
# 18. Original Val: None ---- New Val: nan
# 19. Original Val: None ---- New Val: nan
# 20. Original Val: None ---- New Val: nan
# 21. Original Val: None ---- New Val: Last sale was far below assessed value.
# 22. Original Val: None ---- New Val: nan
# 23. Original Val: None ---- New Val: We understand these properties are owned by PAC and, thus, no compensation is needed.
# 24. Original Val: None ---- New Val: nan
# 25. Original Val: None ---- New Val: We understand these properties are owned by PAC and, thus, no compensation is needed.
# 26. Original Val: None ---- New Val: nan
# 27. Original Val: None ---- New Val: nan
# 28. Original Val: None ---- New Val: nan
# 29. Original Val: None ---- New Val: nan
# 30. Original Val: None ---- New Val: nan
# 31. Original Val: None ---- New Val: nan
# 32. Original Val: None ---- New Val: Last sale was 18 years ago
# 33. Original Val: None ---- New Val: nan
# 34. Original Val: None ---- New Val: nan
# 35. Original Val: None ---- New Val: nan
# 36. Original Val: None ---- New Val: nan
# 37. Original Val: None ---- New Val: nan
# 38. Original Val: None ---- New Val: Low risk property and thus "low" reduction was used.
# 39. Original Val: None ---- New Val: nan
# 40. Original Val: None ---- New Val: nan
# 41. Original Val: None ---- New Val: nan
# STRING  notes

# %%
add_apns = [r'040-250-100', r'041-070-170', r'040-250-100', r'040-230-100', r'103-040-100']
add_apns = [r'{}-000'.format(a) for a in add_apns]
sql_apns = "'"+"', '".join(add_apns) +"'"
sql_apns
# Out:
# "'040-250-100-000', '041-070-170-000', '040-250-100-000', '040-230-100-000', '103-040-100-000'"

# %%
import xml.etree.ElementTree as ET
import os
import pandas as pd
#20230124
# Load xml and tree
shp_dir = r'D:\box_offline\klamath\temp\temp_delete25'
xml = os.path.join(shp_dir, r'wetlands_merged_CA_SP1.shp.xml')
shp = os.path.join(shp_dir, r'wetlands_merged_CA_SP1.shp')
tree = ET.parse(xml)
# root is the root ELEMENT of a tree
root = tree.getroot()
dataIdInfo = root.find('dataIdInfo')
eainfo = root.find('eainfo')

# %%
# 20230124
# Create xml node dictionary
# 1) save all fields to csv
feat = r'wetlands_merged_CA_SP1'
csv = os.path.join(shp_dir, 'wetlands_merged_CA_SP1_xml_template.csv')
flds = [f.name for f in arcpy.ListFields(shp)]
df_fields = pd.DataFrame(flds)
df_fields.to_csv(csv)

# 2) open csv, add target nodes and vals for key/val and Reload
# dataframe dictionary
df_xml_trans = pd.read_csv(csv, index_col = 'attrlabl')

# %%
# 20230124 
# should be valid for fields with FGDC
temp = eainfo.find('detailed')

# If more nodes requiring updates from df add to tgt_nodes list
tgt_nodes = ['attrdef','attrdefs']
attr_child = temp.findall('attr')
for c in attr_child:
    try:
        attrlabl = c.find('attrlabl').text
        for nd in tgt_nodes:
            try:
                v = df_xml_trans.loc[attrlabl, nd]
                # No value from csv/dataframe i.e. no value to replace
                if not pd.isnull(v):
                    c.find(nd).text = df_xml_trans.loc[attrlabl, nd]
                    print('Replaced: {} with: {}'.format(c.find(nd).text, v))
            except KeyError:
                print('Key: {} not present in dataframe'.format(attrlabl))
            except AttributeError:
                # if NoneType --> tgt_node needs to be created and populated in xml
                ET.SubElement(c, nd)
                c.find(nd).text = df_xml_trans.loc[attrlabl, nd]
                print('Created new subelement: {} in {}'.format(nd, attrlabl))
    except KeyError:
        print('The following Key does not have attrlabl: {}'.format(c.tag, c.attr))

tree.write(os.path.join(shp_dir, xml))
# Out:
# Created new subelement: attrdef in WETLAND_ID
# Created new subelement: attrdefs in WETLAND_ID
# Created new subelement: attrdefs in HYDROLOGY
# Created new subelement: attrdef in RESERVOIR
# Created new subelement: attrdef in page_num
# Created new subelement: attrdef in page_name

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\groundwater\merged_concat.csv')
# idx_dups = df[df.duplicated(subset = ['APN'])].APN
# df['duplicated_apns']=False
# df = df.set_index('APN')
# df.loc[idx_dups, 'duplicated_apns'] = True
# df.to_csv(r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\groundwater\merged_concat.csv')

# %%
# df_dups = df[df.duplicated_apns]
# df_dups.to_csv(r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\groundwater\duplicates_merged_concat.csv')
df['non_pertinent_parcel'] = df.non_pertinent_parcel.replace({np.nan:False})
df.to_csv(r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\groundwater\merged_concat.csv')

# %%
# Get count of unique owners
import os
# proj_dir = r'C:\Users\UhlmannZachary\Box\GIS\Project_Based\Klamath_River_Renewal_MJA\GIS_Request_Tracking\GIS_Requests_from_McMillen\20230112\groundwater'
# df_pertinent = df[~df['non_pertinent_parcel']]
# df_counts = df_pertinent.groupby(['PSTLADDRES','AssesseeNa']).size()
# df_counts.to_csv(os.path.join(proj_dir, 'unique_owner.csv'))
# Out:
# 577

# %%
df = pd.read_csv(os.path.join(proj_dir, r'march2020_groundwater_list_zu_20230207.csv'))
apn = [a for a in df.APN.to_list() if not pd.isnull(a)]
apn = ['{}-000'.format(a.strip()) for a in apn]
apn
# Out:
# ['004-400-501-000', '004-420-031-000', '041-040-310-000', '102-061-110-000', '004-420-081-000', '004-440-311-000', '004-480-261-000', '102-061-100-000', '041-040-220-000', '102-240-150-000', '004-480-221-000', '041-410-060-000', '102-330-090-000', '041-410-010-000', '102-370-090-000', '041-040-230-000', '102-340-270-000', '004-440-451-000', '004-450-471-000', '004-400-531-000', '004-400-521-000', '102-280-040-000', '102-280-020-000', '004-410-011-000', '004-410-251-000', '102-300-080-000', '102-120-150-000', '102-061-120-000', '041-030-150-000', '102-270-190-000', '103-010-220-000', '102-061-130-000', '102-260-160-000', '004-030-481-000', '041-410-070-000', '041-060-170-000', '041-030-160-000', '041-040-260-000', '004-440-021-000', '004-440-051-000', '102-260-260-000', '102-280-030-000', '102-200-120-000', '102-350-050-000', '102-350-140-000', '004-440-281-000', '041-010-110-000', '103-260-100-000', '004-030-421-000', '004-450-511-000', '104-050-170-000']
